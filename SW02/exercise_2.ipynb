# %% [markdown]
# # Exercise 2
# ## (c)

# %%
import numpy as np
import matplotlib.pyplot as plt

def sigmoid(z):
    return 1/(1 + np.exp(-z))

def zeta(z):
    return -1 * np.log(sigmoid(-z))

def zeta_prime(z):
    return 1-sigmoid(-z) 

def zeta_prime_prime(z):
    return sigmoid(-z) * (1-sigmoid(-z))

x = np.linspace(-7,7,100)
z = zeta(x)
z1 = zeta_prime(x)
z2 = zeta_prime_prime(x)

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('zero')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

# plot the function
plt.plot(x, z, 'r', label=r'$\zeta$')
plt.plot(x, z1, 'g', label=r'$\zeta^\prime$')
plt.plot(x, z2, 'b', label=r'$\zeta^{\prime\prime}$')

plt.ylim([0, 3])
plt.legend()
plt.title('Exercise 2.c')

# show the plot
plt.show()

# %% [markdown]
# ## (d)

# %%
import numpy as np
import matplotlib.pyplot as plt

def sigmoid(z):
    return 1/(1 + np.exp(-z))

def sigmoid_prime(z):
    return sigmoid(z) * (1 - sigmoid(z))

x = np.linspace(-7,7,100)
sig = sigmoid(x)
sig1 = sigmoid_prime(x)

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('zero')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

# plot the function
plt.plot(x, z, 'r', label=r'$\sigma$')
plt.plot(x, z1, 'g', label=r'$\sigma^{\prime}$')

plt.ylim([0, 3])
plt.legend()
plt.title('Exercise 2.d')

# show the plot
plt.show()
